# %%
import pandas as pd
from datetime import date
import calendar
import pprint
import numpy as np
import sys
import os
import glob as glob

pd.options.display.max_columns = 999
pd.options.display.max_rows = 2000

#Accounting Software Control Sheet
control_sheet_df= pd.DataFrame()
control_sheet_data = glob.glob(r'C:\Users\paulc\Documents\QB NPC Import\Subway\Accounting Software Control Sheet\*')

for file in control_sheet_data:
    df = pd.read_excel(file)
    df.columns = df.iloc[3]
    df.drop(df.index[0:4],inplace=True)
    df = df.reset_index(drop=True)
    control_sheet_df = control_sheet_df.append(df, sort=False)

control_sheet_df = control_sheet_df.reset_index(drop=True)
control_sheet_df = control_sheet_df.infer_objects()


#Royalty/FAF/IPC Data Frame
roy_faf_ipc_df = control_sheet_df.copy(deep=True)
roy_faf_ipc_df = roy_faf_ipc_df[['Store Number',
                               'Date',
                               'Cashcards',
                               'Cash Card Sales',
                               'Catering Call Center',
                               'PayPal',
                               'Unit Sales',
                               'Drinks Sales',
                               'Misc Sales' ]]

roy_faf_ipc_df= roy_faf_ipc_df.groupby(['Store Number'], as_index=False).sum()
roy_faf_ipc_df['Total Sales'] = roy_faf_ipc_df['Unit Sales'] + roy_faf_ipc_df['Drinks Sales'] + roy_faf_ipc_df['Misc Sales']
roy_faf_ipc_df['Royalty'] = roy_faf_ipc_df['Total Sales'] * .08
roy_faf_ipc_df['Faf'] = roy_faf_ipc_df['Total Sales'] * .045
roy_faf_ipc_df['Commission'] = roy_faf_ipc_df['Cash Card Sales'] * .025
roy_faf_ipc_df['Fees'] = ((roy_faf_ipc_df['Catering Call Center'] * .07) + (roy_faf_ipc_df['Cashcards'] * .025) + (roy_faf_ipc_df['PayPal'] * .02))
roy_faf_ipc_df['Net IPC'] = roy_faf_ipc_df['Catering Call Center'] + roy_faf_ipc_df['Cashcards'] - roy_faf_ipc_df['Cash Card Sales'] + roy_faf_ipc_df['Commission'] - roy_faf_ipc_df['Fees'] + roy_faf_ipc_df['PayPal']
roy_faf_ipc_df['Cash Card Sales Commission'] = roy_faf_ipc_df['Cash Card Sales'] * .025
roy_faf_ipc_df['Cash Card Redeemed Fee 2.5%'] = roy_faf_ipc_df['Cashcards'] * .025
roy_faf_ipc_df['Paypal Fee 2%'] = roy_faf_ipc_df['PayPal'] * .02
roy_faf_ipc_df['7% Call Center'] = roy_faf_ipc_df['Catering Call Center'] * .07
roy_faf_ipc_df = roy_faf_ipc_df.round(4)


#Report Group
report_group_df = pd.DataFrame()
report_group_data = glob.glob(r'C:\Users\paulc\Documents\QB NPC Import\Subway\Accounting Report Group\*')

for file in report_group_data:
    df = pd.read_excel(file)
    df.columns = df.iloc[6]
    df.drop(df.index[0:7],inplace=True)
    df = df.reset_index(drop=True)
    df = df[~df.Store.str.contains("Total")]
    df = df[~df.Store.str.contains("GRAND TOTAL")]
    if 'Tender APP' in df.columns:
        pass
    else:
        df['Tender APP'] = 0
    
    if 'Tender RewardsCard' in df.columns:
        pass
    else:
        df['Tender RewardsCard'] = 0

    if 'Tender OTHER A/R' in df.columns:
        pass
    else:
        df['Tender OTHER A/R'] = 0
    
    report_group_df = report_group_df.append(df, sort=False)
    

    

    
#Delivery Data DF    
delivery_data_df = report_group_df.copy(deep=True)
delivery_data_df = delivery_data_df.infer_objects()

delivery_data_df = delivery_data_df[['Date',
                                     'Store',
                                     'Tender Amex',
                                     'Tender APP',
                                     'Tender Cash',
                                     'Tender CashCard',
                                     'Tender Catering Center',
                                     'Tender DEL-DOORDASH',
                                     'Tender DEL-Grubhub',
                                     'Tender DEL-Postmates',
                                     'Tender DEL-UberEatS',
                                     'Tender Discover',
                                     'Tender EBT',
                                     'Tender MasterCard',
                                     'Tender No Tender Type',
                                     'Tender PayPal',
                                     'Tender RewardsCard',
                                     'Tender VISA',
                                     'Tender OTHER A/R']]

delivery_data_df['Daily Delivery Sum'] = delivery_data_df['Tender DEL-DOORDASH'] + delivery_data_df['Tender DEL-Grubhub'] + delivery_data_df['Tender DEL-Postmates'] + delivery_data_df['Tender EBT']
delivery_data_df['Other'] = delivery_data_df['Tender EBT']

delivery_data_df = delivery_data_df.groupby(['Date','Store'], as_index=False).sum()

trnsid = 'WCS-' + control_sheet_df['Store Number']
delivery_trnsid = 'WCS-' + delivery_data_df['Store']
class_list = control_sheet_df['Store Number']
delivery_class_list = delivery_data_df['Store']
date_list = control_sheet_df['Date']
delivery_date_list = delivery_data_df['Date']
class_list = control_sheet_df['Store Number']
delivery_class_list = delivery_data_df['Store']
store_number = control_sheet_df['Store Number']
delivery_store_number = delivery_data_df['Store']


df_batchimport = pd.DataFrame({'TRNSID': trnsid,
                               'Amount': 0.00,
                               'Memo': 'Batch Import',
                               'Class' : class_list,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': date_list,
                               '!TRNS': 'Yes',
                              'ACCNT': 1155})

df_deposits = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': control_sheet_df['Deposit In Bank'],
                            'Memo': 'Cash-' + store_number , 
                            'Class' : class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': date_list,
                            'ACCNT': 1080})


df_cashcards = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Cashcards'],
                             'Memo': 'Cashcards-' + store_number,
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                             'ACCNT': 2450 })

df_cashcard_sales = pd.DataFrame({'TRNSID': trnsid,
                                      'Amount': control_sheet_df['Cash Card Sales'] * -1,
                                      'Memo': 'Cashcard Sales-' + store_number,
                                      'Class' : class_list,
                                      'TRNSTYPE': 'GENERAL JOURNAL',
                                      'Date': date_list,
                                  'ACCNT': 2450 })

df_catering_call_center = pd.DataFrame({'TRNSID': trnsid,
                                      'Amount': (control_sheet_df['Catering Call Center']),
                                      'Memo': 'Catering Call Center-'+ store_number ,
                                      'Class' : class_list,
                                      'TRNSTYPE': 'GENERAL JOURNAL',
                                      'Date': date_list,
                                       'ACCNT': 1130})

df_vmd_credit_sales = pd.DataFrame({'TRNSID': trnsid,
                                    'Amount': control_sheet_df['Visa And Mastercard'] + control_sheet_df['Discover'],
                                    'Memo': 'CC Deposits(VMD)-' + store_number,
                                    'Class' : class_list,
                                    'TRNSTYPE': 'GENERAL JOURNAL',
                                    'Date': date_list,
                                   'ACCNT': 1030})

df_amex_credit_sales = pd.DataFrame({'TRNSID': trnsid,
                                     'Amount': control_sheet_df['American Express'],
                                     'Memo': 'Amex-' + store_number,
                                     'Class' : class_list,
                                     'TRNSTYPE': 'GENERAL JOURNAL',
                                     'Date': date_list,
                                    'ACCNT': 1030 })

df_paid_outs = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Paidouts'],
                             'Memo': 'Paid Outs-'+ store_number ,
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                            'ACCNT': 1060})

df_over_short = pd.DataFrame({'TRNSID': trnsid,
                              'Amount': control_sheet_df['Over Short'] * -1,
                              'Memo': 'Over/Short',
                              'Class' : class_list,
                              'TRNSTYPE': 'GENERAL JOURNAL',
                              'Date': date_list,
                             'ACCNT': 5730})

df_opencash = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': control_sheet_df['Opening Cash'] * -1,
                            'Memo': 'Open Cash',
                            'Class' : class_list,
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': date_list,
                           'ACCNT': 1155})

df_closekeep = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Closing Keep'],
                             'Memo': 'Close Keep',
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                            'ACCNT': 1155})

df_salestax = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': control_sheet_df['Sales Tax'] * -1,
                            'Memo': 'Sales Tax',
                            'Class' : class_list,
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': date_list,
                            'Name': 'SBOE',
                           'ACCNT': 2600})

df_footlong = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': control_sheet_df['Footlong'] * -1,
                            'Memo': 'Footlong',
                            'Class' : class_list,
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': date_list,
                           'ACCNT': 4105})

df_sixinch = pd.DataFrame({'TRNSID': trnsid,
                           'Amount': control_sheet_df['Six Inch'] * -1, 
                           'Memo': 'Six Inch',
                           'Class' : class_list,
                           'TRNSTYPE': 'GENERAL JOURNAL',
                           'Date': date_list,
                          'ACCNT': 4110})

df_threeinch = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Three Inch'] *-1,
                             'Memo': 'Three Inch',
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                            'ACCNT': 4115})

df_muffin = pd.DataFrame({'TRNSID': trnsid,
                          'Amount': control_sheet_df['Muffin'] *-1,
                          'Memo': 'Muffin',
                          'Class' : class_list,
                          'TRNSTYPE': 'GENERAL JOURNAL',
                          'Date': date_list,
                         'ACCNT': 4120})

df_salad = pd.DataFrame({'TRNSID': trnsid,
                         'Amount': control_sheet_df['Salad'] *-1, 
                         'Memo': 'Salad',
                         'Class' : class_list,
                         'TRNSTYPE': 'GENERAL JOURNAL',
                         'Date': date_list,
                        'ACCNT': 4125})

df_pizza = pd.DataFrame({'TRNSID': trnsid,
                         'Amount': control_sheet_df['Pizza'] *-1, 
                         'Memo': 'Pizza',
                         'Class' : class_list,
                         'TRNSTYPE': 'GENERAL JOURNAL',
                         'Date': date_list,
                        'ACCNT': 4130})

df_othercarrier = pd.DataFrame({'TRNSID': trnsid,
                                'Amount': control_sheet_df['Other Carrier'] *-1,
                                'Memo': 'Other Carier',
                                'Class' : class_list,
                                'TRNSTYPE': 'GENERAL JOURNAL',
                                'Date': date_list,
                               'ACCNT': 4135})

df_addon = pd.DataFrame({'TRNSID': trnsid,
                         'Amount': control_sheet_df['Add On'] *-1,
                         'Memo': 'Add On',
                         'Class' : class_list,
                         'TRNSTYPE': 'GENERAL JOURNAL',
                         'Date': date_list,
                        'ACCNT': 4140})

df_catering_1 = pd.DataFrame({'TRNSID': trnsid,
                              'Amount': control_sheet_df['Catering'] *-1,
                              'Memo': 'Catering',
                              'Class' : class_list,
                              'TRNSTYPE': 'GENERAL JOURNAL',
                              'Date': date_list,
                             'ACCNT': 4145})

df_unitcouponsdisc = pd.DataFrame({'TRNSID': trnsid,
                                   'Amount': control_sheet_df['Unit Coupons Disc.'] *-1,
                                   'Memo': 'Unit Coupon Disc',
                                   'Class' : class_list,
                                   'TRNSTYPE': 'GENERAL JOURNAL',
                                   'Date': date_list,
                                  'ACCNT': 4150})

df_unitrefunds = pd.DataFrame({'TRNSID': trnsid,
                               'Amount': control_sheet_df['Unit Refunds'] *-1,
                               'Memo': 'Unit Refunds',
                               'Class' : class_list,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': date_list,
                              'ACCNT': 4155})

df_unitvoids = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Unit Voids'] *-1,
                             'Memo': 'Unit Voids',
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                            'ACCNT': 4160 })

df_fountain = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': control_sheet_df['Fountain'] *-1,
                            'Memo': 'Fountain',
                            'Class' : class_list,
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': date_list,
                           'ACCNT': 4205})

df_bottledbeverage = pd.DataFrame({'TRNSID': trnsid,
                                   'Amount': control_sheet_df['Bottled Beverage'] *-1,
                                   'Memo': 'Bottle Beverage',
                                   'Class' : class_list,
                                   'TRNSTYPE': 'GENERAL JOURNAL',
                                   'Date': date_list,
                                  'ACCNT': 4210})

df_hotbeverage = pd.DataFrame({'TRNSID': trnsid,
                               'Amount': control_sheet_df['Hot Beverage'] *-1,
                               'Memo': 'Hot Beverage',
                               'Class' : class_list,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': date_list,
                              'ACCNT': 4215})

df_otherbeverage = pd.DataFrame({'TRNSID': trnsid,
                                 'Amount': control_sheet_df['Other Beverage'] *-1,
                                 'Memo': 'Other Beverage',
                                 'Class' : class_list,
                                 'TRNSTYPE': 'GENERAL JOURNAL',
                                 'Date': date_list,
                                'ACCNT': 4220})

df_drinkscouponsdisc = pd.DataFrame({'TRNSID': trnsid,
                                     'Amount': control_sheet_df['Drinks Coupons Disc.'] *-1,
                                     'Memo': 'Drinks Coupons Disc.',
                                     'Class' : class_list,
                                     'TRNSTYPE': 'GENERAL JOURNAL',
                                     'Date': date_list,
                                    'ACCNT': 4225})

df_drinksrefund = pd.DataFrame({'TRNSID': trnsid,
                                'Amount': control_sheet_df['Drinks Refunds'] *-1,
                                'Memo': 'Drinks Refunds',
                                'Class' : class_list,
                                'TRNSTYPE': 'GENERAL JOURNAL',
                                'Date': date_list,
                               'ACCNT': 4230})

df_drinksvoids = pd.DataFrame({'TRNSID': trnsid,
                               'Amount': control_sheet_df['Drinks Voids'] *-1,
                               'Memo': 'Drinks Voids',
                               'Class' : class_list,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': date_list,
                              'ACCNT': 4235})

df_chips = pd.DataFrame({'TRNSID': trnsid,
                         'Amount': control_sheet_df['Chips'] *-1,
                         'Memo': 'Chips',
                         'Class' : class_list,
                         'TRNSTYPE': 'GENERAL JOURNAL',
                         'Date': date_list,
                        'ACCNT': 4305})

df_cookies = pd.DataFrame({'TRNSID': trnsid,
                           'Amount': control_sheet_df['Cookies'] *-1,
                           'Memo': 'Cookies',
                           'Class' : class_list,
                           'TRNSTYPE': 'GENERAL JOURNAL',
                           'Date': date_list,
                          'ACCNT': 4310})

df_soups = pd.DataFrame({'TRNSID': trnsid,
                         'Amount': control_sheet_df['Soups'] *-1,
                         'Memo': 'Soups',
                         'Class' : class_list,
                         'TRNSTYPE': 'GENERAL JOURNAL',
                         'Date': date_list,
                        'ACCNT': 4315})

df_othermisc = pd.DataFrame({'TRNSID': trnsid,
                             'Amount': control_sheet_df['Other Misc'] *-1,
                             'Memo': 'Other Misc',
                             'Class' : class_list,
                             'TRNSTYPE': 'GENERAL JOURNAL',
                             'Date': date_list,
                            'ACCNT': 4320})

df_othercouponsdisc = pd.DataFrame({'TRNSID': trnsid,
                                    'Amount': control_sheet_df['Other Coupons Disc.'] *-1,
                                    'Memo': 'Other Coupons Disc.',
                                    'Class' : class_list,
                                    'TRNSTYPE': 'GENERAL JOURNAL',
                                    'Date': date_list,
                                   'ACCNT': 4325})

df_otherrefunds = pd.DataFrame({'TRNSID': trnsid,
                                'Amount': control_sheet_df['Other Refunds'] *-1,
                                'Memo': 'Other Refunds',
                                'Class' : class_list,
                                'TRNSTYPE': 'GENERAL JOURNAL',
                                'Date': date_list,
                               'ACCNT': 4330})

df_othervoids = pd.DataFrame({'TRNSID': trnsid,
                              'Amount': control_sheet_df['Other Voids'] *-1,
                              'Memo': 'Other Voids',
                              'Class' : class_list,
                              'TRNSTYPE': 'GENERAL JOURNAL',
                              'Date': date_list,
                             'ACCNT': 4335})

df_otherreceipts = pd.DataFrame({'TRNSID': trnsid,
                                 'Amount': control_sheet_df['Other Receipts'] *-1,
                                 'Memo': 'Other Receipts',
                                 'Class' : class_list,
                                 'TRNSTYPE': 'GENERAL JOURNAL',
                                 'Date': date_list,
                                'ACCNT': 4400 })


df_doordash = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-DOORDASH'],
                            'Memo': 'Doordash-'  + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                           'ACCNT': 1124 })

df_grubhub = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-Grubhub'],
                            'Memo': 'GrubHub-'  + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                          'ACCNT': 1122 })

df_postmates = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-Postmates'],
                            'Memo': 'Postmates-'  + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                            'ACCNT': 1121})

df_ubereats = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-UberEatS'],
                            'Memo': 'Uber Eats-'  + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                           'ACCNT': 1123})

df_delivery_daily_sales = pd.DataFrame({'TRNSID': delivery_trnsid,
                                        'Amount': delivery_data_df['Tender DEL-DOORDASH'] + delivery_data_df['Tender DEL-Grubhub'] + delivery_data_df['Tender DEL-Postmates'] + delivery_data_df['Tender DEL-UberEatS'],
                                        'Memo': 'Daily Delivery Sales Offset',
                                        'Class' : delivery_class_list, 
                                        'TRNSTYPE': 'GENERAL JOURNAL',
                                        'Date': delivery_date_list,
                                       'ACCNT': 4459})

df_doordash_sales = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-DOORDASH'] * -1,
                            'Memo': 'Doordash-Sales', 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                                 'ACCNT': 4451})

df_grubhub_sales = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-Grubhub']  * -1,
                            'Memo': 'GrubHub-Sales', 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                                'ACCNT': 4452})

df_postmates_sales = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-Postmates'] * -1,
                            'Memo': 'Postmates-Sales', 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                                  'ACCNT': 4453})

df_ubereats_sales = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender DEL-UberEatS'] *-1,
                            'Memo': 'Uber Eats-Sales', 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                                 'ACCNT': 4454})

df_tender_paypal = pd.DataFrame({'TRNSID': trnsid,
                            'Amount': delivery_data_df['Tender PayPal'],
                            'Memo': 'Tender Pay Pal-'+ store_number , 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                                'ACCNT': 1165})

df_tender_ebt = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender EBT'],
                            'Memo': 'EBT-' + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                             'ACCNT': 1030 })

df_other_ar = pd.DataFrame({'TRNSID': delivery_trnsid,
                            'Amount': delivery_data_df['Tender OTHER A/R'],
                            'Memo': 'Other AR-' + delivery_store_number, 
                            'Class' : delivery_class_list, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': delivery_date_list,
                             'ACCNT': 1196 })

control_sheet_result = df_deposits.append([df_batchimport,
                                           df_catering_call_center,
                                           df_vmd_credit_sales, 
                                           df_amex_credit_sales,
                                           df_tender_ebt,
                                           df_cashcards,
                                           df_cashcard_sales,
                                           df_paid_outs,
                                           df_tender_paypal,
                                           df_other_ar,
                                           df_over_short, 
                                           df_opencash, 
                                           df_closekeep,
                                           df_salestax, 
                                           df_footlong, 
                                           df_sixinch, 
                                           df_threeinch, 
                                           df_muffin,
                                           df_salad,
                                           df_pizza,
                                           df_othercarrier,
                                           df_addon,
                                           df_catering_1,
                                           df_unitcouponsdisc,
                                           df_unitrefunds,
                                           df_unitvoids,
                                           df_fountain,
                                           df_bottledbeverage,
                                           df_hotbeverage,
                                           df_otherbeverage,
                                           df_drinkscouponsdisc,
                                           df_drinksrefund,
                                           df_drinksvoids,
                                           df_chips,
                                           df_cookies,
                                           df_soups,
                                           df_othermisc,
                                           df_othercouponsdisc,
                                           df_otherrefunds,
                                           df_othervoids,
                                           df_otherreceipts,
                                           df_doordash,
                                           df_grubhub,
                                           df_postmates,
                                           df_ubereats,
                                           df_delivery_daily_sales,
                                           df_doordash_sales,
                                           df_grubhub_sales,
                                           df_postmates_sales,
                                           df_ubereats_sales,
                                          ], sort=False)
                    

control_sheet_result = control_sheet_result[['!TRNS','TRNSID', 'TRNSTYPE', 'Date', 'Amount','ACCNT', 'Memo', 'Class', 'Name', ]]

control_sheet_result = control_sheet_result.sort_values(by = ['Class','Date', '!TRNS'])


roy_faf_transid = 'Combo-' + roy_faf_ipc_df['Store Number']
faf_store_number = roy_faf_ipc_df['Store Number']

WE_DATE = report_group_df['Date'].values[-1].strftime("%m/%d/%y").replace('/', '-')

df_roy_faf_batchimport = pd.DataFrame({'TRNSID': roy_faf_transid,
                               'Amount': 0.00,
                               'Memo': 'Batch Import',
                               'Class' : faf_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                               '!TRNS': 'Yes',
                              'ACCNT': 1155})

df_cash_faf = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': roy_faf_ipc_df['Faf'] * -1,
                            'Memo': 'Faf-Royalty-' + faf_store_number , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 1030,
                           'Name': faf_store_number})

df_royalty = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': roy_faf_ipc_df['Royalty'] * -1,
                            'Memo': 'DAI Royalty-' + faf_store_number , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 1030,
                          'Name': faf_store_number})

df_faf_fees = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': roy_faf_ipc_df['Faf'],
                            'Memo': 'Fees-Faf' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 5550})

df_royalty_fees = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': roy_faf_ipc_df['Royalty'] ,
                            'Memo': 'Fees-Royalty' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 5370})

df_loyalty_food_cost_REIM = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': 0,
                            'Memo': 'Loyalty Food Cost REIM' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 5090})

df_loyalty_food_cost_free_REIM = pd.DataFrame({'TRNSID': roy_faf_transid,
                                               'Amount': 0,
                                               'Memo': 'Loyalty Food Cost Free REIM' , 
                                               'Class' : faf_store_number, 
                                               'TRNSTYPE': 'GENERAL JOURNAL',
                                               'Date': WE_DATE,
                                               'ACCNT': 5090})

df_loyalty_sales_tax_payable = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': 0,
                            'Memo': 'Loyalty Sales Tax Payable' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 2610})

df_loyalty_sales_tax_payable = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': 0,
                            'Memo': 'Loyalty Sales Tax Payable' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 2610})

df_tbd_waiver_royalty = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': 0,
                            'Memo': 'TBD-Waiver-ROI' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 5375})

df_tbd_waiver_advertising = pd.DataFrame({'TRNSID': roy_faf_transid,
                            'Amount': 0,
                            'Memo': 'TPD-Waiver_Ad-Fee' , 
                            'Class' : faf_store_number, 
                            'TRNSTYPE': 'GENERAL JOURNAL',
                            'Date': WE_DATE,
                            'ACCNT': 5555})

roy_faf_result = df_roy_faf_batchimport.append([df_cash_faf,
                                                df_royalty,
                                                df_faf_fees,
                                                df_royalty_fees,
                                                df_loyalty_food_cost_REIM,
                                                df_loyalty_food_cost_free_REIM,
                                                df_loyalty_sales_tax_payable,
                                                df_tbd_waiver_royalty,
                                                df_tbd_waiver_advertising], sort=False)


roy_faf_result = roy_faf_result[['!TRNS','TRNSID', 'TRNSTYPE', 'Date', 'Amount','ACCNT', 'Memo', 'Class', 'Name']]

roy_faf_result = roy_faf_result.sort_values(by = ['Class','Memo'])

ipc_transid = 'IPC-' + roy_faf_ipc_df['Store Number']
ipc_store_number = roy_faf_ipc_df['Store Number']


df_ipc_batchimport = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': 0 ,
                               'Memo': 'Batch Import',
                               'Class' : faf_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                               '!TRNS': 'Yes',
                              'ACCNT': 1155})

df_call_fee = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['7% Call Center'],
                               'Memo': 'Call Fee',
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 5783 })

df_cash_card_redeemed_fee = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Cash Card Redeemed Fee 2.5%'],
                               'Memo': 'Cash Card Redeemed Fee',
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 5782 })

df_cash_card_comm = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Cash Card Sales Commission'] * -1,
                               'Memo': 'Cash Card Sales Commission',
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 8050 })

df_paypal_fee = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Paypal Fee 2%'],
                               'Memo': 'Paypal Fee-' + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 5785 })

df_ipc_catering_call_center = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Catering Call Center'] * -1,
                               'Memo': 'Catering Call Center-'+ ipc_store_number ,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 1130 })

df_ipc_cash_card_sales = pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Cash Card Sales'],
                               'Memo': 'Cash Card Sales-' + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 2450 })

df_ipc_cash_card_redeeemed= pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Cashcards'] * -1,
                               'Memo': 'Cash Card Redeemed-' + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 2450 })

df_ipc_net_deposit= pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['Net IPC'],
                               'Memo': 'IPC Net Deposit-' + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 1030 })

df_ipc_paypal= pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': roy_faf_ipc_df['PayPal'] * -1,
                               'Memo': 'Paypal-'  + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 1165 })

df_cnp_fees= pd.DataFrame({'TRNSID': ipc_transid,
                               'Amount': 0,
                               'Memo': 'CNP Fees-'  + ipc_store_number,
                               'Class' : ipc_store_number,
                               'TRNSTYPE': 'GENERAL JOURNAL',
                               'Date': WE_DATE,
                              'ACCNT': 5787 })

ipc_result = df_ipc_batchimport.append([df_ipc_net_deposit,
                                        df_call_fee,
                                        df_cash_card_redeemed_fee,
                                        df_cash_card_comm,
                                        df_paypal_fee,
                                        df_ipc_catering_call_center,
                                        df_ipc_cash_card_sales,
                                        df_ipc_cash_card_redeeemed,
                                        df_ipc_paypal,
                                        df_cnp_fees], sort = False)

ipc_result = ipc_result[['!TRNS','TRNSID', 'TRNSTYPE', 'Date', 'Amount','ACCNT', 'Memo', 'Class']]

ipc_result = ipc_result.sort_values(by = ['Class','Memo'])

final_result = control_sheet_result.append([roy_faf_result,
                                           ipc_result], sort=False)

final_result['Date'] = pd.to_datetime(final_result['Date'])


final_result = final_result[['!TRNS',
                             'TRNSID',
                             'TRNSTYPE',
                             'Date',
                             'Amount',
                             'ACCNT',
                             'Memo',
                             'Class',
                            'Name']]

file_name = '\Final Result Export-WE-' + str(WE_DATE) + '.xlsx'

final_result_exlude_55799 = final_result.copy(deep=True)
final_result_exlude_55799 = final_result_exlude_55799[final_result_exlude_55799['Class'] != str(55799)]
final_result_exlude_55799['Date'] = final_result_exlude_55799['Date'].astype(str)
final_result_exlude_55799['Class'] = final_result_exlude_55799['Class'].astype(int)



#writer = pd.ExcelWriter(r'C:\Users\paulc\Documents\QB NPC Import\Subway\Results' + file_name)
#final_result_exlude_55799.to_excel(writer,'Sheet1', index=False)
#writer.save()

print("Export Script Completed")

final_result_exlude_55799
# Out:
# Export Script Completed
#    !TRNS       TRNSID         TRNSTYPE        Date     Amount  ACCNT  \
# 0    Yes    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1155
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   615.6000   1080
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1130
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   530.2300   1030
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1030
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   138.1000   1030
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    23.4900   2450
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   2450
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1060
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1165
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1196
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.4800   5730
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23  -200.0000   1155
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   200.0000   1155
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -65.1300   2600
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23  -803.3800   4105
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23  -222.9700   4110
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4115
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4120
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -15.4800   4125
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4130
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -76.4100   4135
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -44.0000   4140
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4145
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   164.3000   4150
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4155
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     8.4900   4160
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -86.6200   4205
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -40.1200   4210
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -1.7900   4215
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4220
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    13.9700   4225
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4230
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4235
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -82.0100   4305
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -29.6900   4310
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -46.6200   4315
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -26.0000   4320
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    15.5000   4325
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4330
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4335
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4400
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1124
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1122
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1121
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    30.0600   1123
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    30.0600   4459
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4451
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4452
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23    -0.0000   4453
# 0    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23   -30.0600   4454
# 1    Yes    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1155
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   346.2300   1080
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1130
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   330.5100   1030
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1030
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   140.7100   1030
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   2450
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   2450
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1060
# 14   NaN     WCS-1717  GENERAL JOURNAL  2019-01-24     0.0000   1165
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1196
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   5730
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24  -200.0000   1155
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   200.0000   1155
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -35.5700   2600
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24  -572.2600   4105
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24  -136.9400   4110
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4115
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4120
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -20.9700   4125
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4130
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -34.9500   4135
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -22.5000   4140
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4145
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    96.0600   4150
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4155
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    13.9800   4160
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -37.2400   4205
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -31.2700   4210
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4215
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4220
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     6.3100   4225
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4230
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4235
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -29.1900   4305
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -23.5000   4310
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -15.5400   4315
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -15.0000   4320
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     4.3600   4325
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4330
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4335
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4400
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    10.9600   1124
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24     0.0000   1122
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    10.8300   1121
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    14.9800   1123
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    36.7700   4459
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -10.9600   4451
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24    -0.0000   4452
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -10.8300   4453
# 14   NaN    WCS-10086  GENERAL JOURNAL  2019-01-24   -14.9800   4454
# 2    Yes    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1155
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   408.4900   1080
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1130
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   360.9600   1030
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    22.0700   1030
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    89.5400   1030
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    15.9800   2450
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   2450
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1060
# 28   NaN    WCS-23339  GENERAL JOURNAL  2019-01-25     0.0000   1165
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1196
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   5730
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25  -200.0000   1155
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   200.0000   1155
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -42.0300   2600
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25  -519.0300   4105
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25  -200.3100   4110
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4115
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4120
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -6.9900   4125
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4130
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -52.9500   4135
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -15.0000   4140
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4145
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    82.3600   4150
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4155
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4160
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -59.7400   4205
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -33.8400   4210
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4215
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4220
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     7.0400   4225
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4230
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4235
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -45.8700   4305
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -26.9100   4310
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -12.9500   4315
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -31.0000   4320
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    10.9800   4325
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4330
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4335
# 2    NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4400
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1124
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1122
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25     0.0000   1121
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    49.2000   1123
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    49.2000   4459
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4451
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4452
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25    -0.0000   4453
# 28   NaN    WCS-10086  GENERAL JOURNAL  2019-01-25   -49.2000   4454
# 3    Yes    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1155
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   481.3800   1080
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1130
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   285.1900   1030
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1030
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    80.9300   1030
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    15.7900   2450
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   2450
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1060
# 42   NaN    WCS-34939  GENERAL JOURNAL  2019-01-26     0.0000   1165
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1196
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   5730
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26  -200.0000   1155
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   200.0000   1155
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -44.9200   2600
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26  -628.0900   4105
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26  -138.2300   4110
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4115
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4120
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -6.9900   4125
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4130
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -6.9900   4135
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -26.0000   4140
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4145
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    98.4600   4150
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4155
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4160
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -46.8000   4205
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -11.9500   4210
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4215
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4220
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     5.0100   4225
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4230
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4235
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -37.5300   4305
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -24.3500   4310
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -12.9500   4315
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -12.0000   4320
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     4.9600   4325
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4330
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4335
# 3    NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4400
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1124
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1122
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26     0.0000   1121
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    25.0800   1123
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    25.0800   4459
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4451
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4452
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26    -0.0000   4453
# 42   NaN    WCS-10086  GENERAL JOURNAL  2019-01-26   -25.0800   4454
# 4    Yes    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1155
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   323.8100   1080
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1130
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   347.6200   1030
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1030
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    33.7900   1030
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     7.6500   2450
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   2450
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1060
# 56   NaN    WCS-45790  GENERAL JOURNAL  2019-01-27     0.0000   1165
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1196
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   5730
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27  -200.0000   1155
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   200.0000   1155
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -42.0100   2600
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27  -483.9900   4105
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27  -167.4800   4110
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4115
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4120
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4125
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4130
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -6.9900   4135
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -24.7500   4140
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4145
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    91.5900   4150
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     7.9900   4155
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4160
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -27.8800   4205
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -38.3400   4210
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4215
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4220
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    10.7500   4225
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4230
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4235
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -31.9700   4305
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -25.9100   4310
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -15.5400   4315
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -22.0000   4320
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     4.6000   4325
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     6.8900   4330
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4335
# 4    NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4400
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    10.2100   1124
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1122
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27     0.0000   1121
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    41.9600   1123
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    52.1700   4459
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -10.2100   4451
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4452
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27    -0.0000   4453
# 56   NaN    WCS-10086  GENERAL JOURNAL  2019-01-27   -41.9600   4454
# 5    Yes    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1155
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   473.5400   1080
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1130
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   405.7200   1030
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1030
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   153.9100   1030
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    37.9000   2450
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   2450
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1060
# 70   NaN    WCS-55799  GENERAL JOURNAL  2019-01-28     0.0000   1165
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1196
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   5730
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28  -200.0000   1155
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   200.0000   1155
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -56.9600   2600
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28  -673.9400   4105
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28  -224.1700   4110
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4115
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4120
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -29.4600   4125
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4130
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -41.9400   4135
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -21.2500   4140
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4145
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   112.2000   4150
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4155
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4160
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -68.7000   4205
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -21.5100   4210
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -1.7900   4215
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4220
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     9.5200   4225
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4230
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4235
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -58.3800   4305
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -25.9100   4310
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -18.1300   4315
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -27.0000   4320
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     7.8900   4325
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4330
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4335
# 5    NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4400
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    24.7300   1124
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    24.4600   1122
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28     0.0000   1121
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    19.2700   1123
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    68.4600   4459
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -24.7300   4451
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -24.4600   4452
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28    -0.0000   4453
# 70   NaN    WCS-10086  GENERAL JOURNAL  2019-01-28   -19.2700   4454
# 6    Yes    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1155
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   416.3800   1080
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1130
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   370.7400   1030
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1030
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    87.3600   1030
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    24.1800   2450
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   2450
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1060
# 84   NaN    WCS-64160  GENERAL JOURNAL  2019-01-29     0.0000   1165
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1196
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.4200   5730
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29  -200.0000   1155
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   200.0000   1155
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -45.7700   2600
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29  -606.2200   4105
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29  -176.3600   4110
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4115
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4120
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4125
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4130
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -13.9800   4135
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -14.0000   4140
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4145
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    88.2700   4150
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4155
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4160
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -55.7600   4205
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -33.0600   4210
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4215
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4220
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    12.4000   4225
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4230
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4235
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -41.7000   4305
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -31.4700   4310
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -18.1300   4315
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -20.0000   4320
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     6.1100   4325
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4330
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4335
# 6    NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4400
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1124
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    24.4600   1122
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29     0.0000   1121
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    26.1300   1123
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    50.5900   4459
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4451
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -24.4600   4452
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29    -0.0000   4453
# 84   NaN    WCS-10086  GENERAL JOURNAL  2019-01-29   -26.1300   4454
# 7    Yes    WCS-10215  GENERAL JOURNAL  2019-01-23     0.0000   1155
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   232.2800   1080
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23     0.0000   1130
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   262.2600   1030
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    18.6400   1030
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    43.2300   1030
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    43.7900   2450
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -15.0000   2450
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23     0.0000   1060
# 1    NaN    WCS-10086  GENERAL JOURNAL  2019-01-23     0.0000   1165
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23     0.0000   1196
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.9100   5730
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23  -200.0000   1155
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   200.0000   1155
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -42.8100   2600
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23  -297.5200   4105
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23  -180.7500   4110
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4115
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4120
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -13.9800   4125
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4130
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -24.4600   4135
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -20.5000   4140
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4145
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    88.2800   4150
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4155
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4160
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -62.5200   4205
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -21.5100   4210
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4215
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4220
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    11.2100   4225
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4230
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4235
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -38.9200   4305
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -18.4600   4310
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -7.7700   4315
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -35.0000   4320
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23     4.7300   4325
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4330
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4335
# 7    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4400
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    24.9700   1124
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    40.3400   1122
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    10.3800   1121
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23     0.0000   1123
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    75.6900   4459
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -24.9700   4451
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -40.3400   4452
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23   -10.3800   4453
# 1    NaN    WCS-10215  GENERAL JOURNAL  2019-01-23    -0.0000   4454
# 8    Yes    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1155
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   252.7200   1080
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1130
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   362.1100   1030
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1030
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1030
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    21.5100   2450
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   2450
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1060
# 15   NaN     WCS-1717  GENERAL JOURNAL  2019-01-24     0.0000   1165
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1196
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     1.3700   5730
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24  -200.0000   1155
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   200.0000   1155
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -37.5000   2600
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24  -223.5200   4105
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24  -239.2900   4110
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4115
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4120
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -22.4700   4125
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4130
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -24.4600   4135
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -8.5000   4140
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4145
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    57.0900   4150
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4155
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4160
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -67.7000   4205
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -4.7800   4210
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4215
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4220
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     4.2900   4225
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4230
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4235
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -36.1400   4305
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24   -35.0300   4310
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -7.7700   4315
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4320
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     8.0700   4325
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4330
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4335
# 8    NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4400
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1124
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1122
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1121
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   1123
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24     0.0000   4459
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4451
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4452
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4453
# 15   NaN    WCS-10215  GENERAL JOURNAL  2019-01-24    -0.0000   4454
# 9    Yes    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1155
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   272.1900   1080
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1130
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   540.7400   1030
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1030
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    10.7400   1030
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    37.4200   2450
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   2450
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1060
# 29   NaN    WCS-23339  GENERAL JOURNAL  2019-01-25     0.0000   1165
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1196
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0200   5730
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25  -200.0000   1155
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   200.0000   1155
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -62.6200   2600
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25  -290.5300   4105
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25  -238.9800   4110
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4115
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4120
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -15.4800   4125
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4130
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -77.8900   4135
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -22.5000   4140
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4145
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    59.3400   4150
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4155
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     7.9900   4160
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25  -109.9100   4205
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -25.2800   4210
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4215
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4220
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    12.2600   4225
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4230
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4235
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -72.2800   4305
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -33.2900   4310
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -10.3600   4315
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -24.5900   4320
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     8.7300   4325
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4330
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4335
# 9    NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4400
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1124
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1122
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25     0.0000   1121
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    34.3200   1123
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    34.3200   4459
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4451
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4452
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25    -0.0000   4453
# 29   NaN    WCS-10215  GENERAL JOURNAL  2019-01-25   -34.3200   4454
# 10   Yes    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1155
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   243.7700   1080
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1130
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   680.0600   1030
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     8.8900   1030
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     6.3800   1030
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    24.9400   2450
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -39.9900   2450
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1060
# 43   NaN    WCS-34939  GENERAL JOURNAL  2019-01-26     0.0000   1165
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1196
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.9200   5730
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26  -200.0000   1155
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   200.0000   1155
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -62.0200   2600
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26  -412.4600   4105
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26  -254.9000   4110
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4115
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4120
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -6.9900   4125
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4130
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -35.4600   4135
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -24.7500   4140
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4145
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    67.5700   4150
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4155
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4160
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -91.8000   4205
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -37.0400   4210
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4215
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4220
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    14.2000   4225
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4230
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4235
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -62.5500   4305
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -17.4600   4310
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -7.7700   4315
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26   -18.5900   4320
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    16.3100   4325
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     1.3900   4330
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4335
# 10   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4400
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1124
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1122
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     9.1900   1121
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     0.0000   1123
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26     9.1900   4459
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4451
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4452
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -9.1900   4453
# 43   NaN    WCS-10215  GENERAL JOURNAL  2019-01-26    -0.0000   4454
# 11   Yes    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1155
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   451.9300   1080
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1130
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   697.9200   1030
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    15.2400   1030
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    20.3200   1030
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    49.1400   2450
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   2450
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1060
# 57   NaN    WCS-45790  GENERAL JOURNAL  2019-01-27     0.0000   1165
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1196
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.1100   5730
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27  -200.0000   1155
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   200.0000   1155
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -71.5000   2600
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27  -501.7500   4105
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27  -308.9900   4110
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4115
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4120
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -20.9700   4125
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4130
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -22.9700   4135
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -28.2500   4140
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -39.9900   4145
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    78.5600   4150
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4155
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4160
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27  -163.6900   4205
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -42.5200   4210
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4215
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4220
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    14.0300   4225
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4230
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4235
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27  -105.6400   4305
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -22.1300   4310
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -7.7700   4315
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27   -11.0000   4320
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    12.2100   4325
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4330
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4335
# 11   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4400
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1124
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     7.9300   1122
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1121
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     0.0000   1123
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27     7.9300   4459
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4451
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -7.9300   4452
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4453
# 57   NaN    WCS-10215  GENERAL JOURNAL  2019-01-27    -0.0000   4454
# 12   Yes    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1155
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   244.3700   1080
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1130
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   432.2600   1030
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1030
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     6.1800   1030
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    27.3900   2450
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   2450
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1060
# 71   NaN    WCS-55799  GENERAL JOURNAL  2019-01-28     0.0000   1165
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1196
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.1200   5730
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28  -200.0000   1155
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   200.0000   1155
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -53.4600   2600
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28  -266.0800   4105
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28  -224.1200   4110
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4115
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4120
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -27.9600   4125
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4130
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -14.9800   4135
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -27.2500   4140
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4145
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    72.0100   4150
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4155
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     8.9900   4160
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -73.6700   4205
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -43.7100   4210
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4215
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4220
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    12.6200   4225
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4230
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4235
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -56.9900   4305
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28   -19.6800   4310
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -7.7700   4315
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -9.5900   4320
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    13.8700   4325
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4330
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4335
# 12   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4400
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     7.6900   1124
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1122
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1121
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     0.0000   1123
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28     7.6900   4459
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -7.6900   4451
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4452
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4453
# 71   NaN    WCS-10215  GENERAL JOURNAL  2019-01-28    -0.0000   4454
# 13   Yes    WCS-10215  GENERAL JOURNAL  2019-01-29     0.0000   1155
# 13   NaN    WCS-10215  GENERAL JOURNAL  2019-01-29   213.9700   1080
# ...
# 83                  GrubHub-930    930    NaN
# 83                Postmates-930    930    NaN
# 83                Uber Eats-930    930    NaN
# 83  Daily Delivery Sales Offset    930    NaN
# 83               Doordash-Sales    930    NaN
# 83                GrubHub-Sales    930    NaN
# 83              Postmates-Sales    930    NaN
# 83              Uber Eats-Sales    930    NaN
# 97                 Batch Import    930    NaN
# 97                     Cash-930    930    NaN
# 97     Catering Call Center-930    930    NaN
# 97         CC Deposits(VMD)-930    930    NaN
# 97                     Amex-930    930    NaN
# 97                      EBT-930    930    NaN
# 97                Cashcards-930    930    NaN
# 97           Cashcard Sales-930    930    NaN
# 97                Paid Outs-930    930    NaN
# 97           Tender Pay Pal-930    930    NaN
# 97                 Other AR-930    930    NaN
# 97                   Over/Short    930    NaN
# 97                    Open Cash    930    NaN
# 97                   Close Keep    930    NaN
# 97                    Sales Tax    930   SBOE
# 97                     Footlong    930    NaN
# 97                     Six Inch    930    NaN
# 97                   Three Inch    930    NaN
# 97                       Muffin    930    NaN
# 97                        Salad    930    NaN
# 97                        Pizza    930    NaN
# 97                 Other Carier    930    NaN
# 97                       Add On    930    NaN
# 97                     Catering    930    NaN
# 97             Unit Coupon Disc    930    NaN
# 97                 Unit Refunds    930    NaN
# 97                   Unit Voids    930    NaN
# 97                     Fountain    930    NaN
# 97              Bottle Beverage    930    NaN
# 97                 Hot Beverage    930    NaN
# 97               Other Beverage    930    NaN
# 97         Drinks Coupons Disc.    930    NaN
# 97               Drinks Refunds    930    NaN
# 97                 Drinks Voids    930    NaN
# 97                        Chips    930    NaN
# 97                      Cookies    930    NaN
# 97                        Soups    930    NaN
# 97                   Other Misc    930    NaN
# 97          Other Coupons Disc.    930    NaN
# 97                Other Refunds    930    NaN
# 97                  Other Voids    930    NaN
# 97               Other Receipts    930    NaN
# 97                 Doordash-930    930    NaN
# 97                  GrubHub-930    930    NaN
# 97                Postmates-930    930    NaN
# 97                Uber Eats-930    930    NaN
# 97  Daily Delivery Sales Offset    930    NaN
# 97               Doordash-Sales    930    NaN
# 97                GrubHub-Sales    930    NaN
# 97              Postmates-Sales    930    NaN
# 97              Uber Eats-Sales    930    NaN
# 0                  Batch Import  10086    NaN
# 0             DAI Royalty-10086  10086  10086
# 0             Faf-Royalty-10086  10086  10086
# 0                      Fees-Faf  10086    NaN
# 0                  Fees-Royalty  10086    NaN
# 0   Loyalty Food Cost Free REIM  10086    NaN
# 0        Loyalty Food Cost REIM  10086    NaN
# 0     Loyalty Sales Tax Payable  10086    NaN
# 0                TBD-Waiver-ROI  10086    NaN
# 0             TPD-Waiver_Ad-Fee  10086    NaN
# 1                  Batch Import  10215    NaN
# 1             DAI Royalty-10215  10215  10215
# 1             Faf-Royalty-10215  10215  10215
# 1                      Fees-Faf  10215    NaN
# 1                  Fees-Royalty  10215    NaN
# 1   Loyalty Food Cost Free REIM  10215    NaN
# 1        Loyalty Food Cost REIM  10215    NaN
# 1     Loyalty Sales Tax Payable  10215    NaN
# 1                TBD-Waiver-ROI  10215    NaN
# 1             TPD-Waiver_Ad-Fee  10215    NaN
# 2                  Batch Import   1717    NaN
# 2              DAI Royalty-1717   1717   1717
# 2              Faf-Royalty-1717   1717   1717
# 2                      Fees-Faf   1717    NaN
# 2                  Fees-Royalty   1717    NaN
# 2   Loyalty Food Cost Free REIM   1717    NaN
# 2        Loyalty Food Cost REIM   1717    NaN
# 2     Loyalty Sales Tax Payable   1717    NaN
# 2                TBD-Waiver-ROI   1717    NaN
# 2             TPD-Waiver_Ad-Fee   1717    NaN
# 3                  Batch Import  22899    NaN
# 3             DAI Royalty-22899  22899  22899
# 3             Faf-Royalty-22899  22899  22899
# 3                      Fees-Faf  22899    NaN
# 3                  Fees-Royalty  22899    NaN
# 3   Loyalty Food Cost Free REIM  22899    NaN
# 3        Loyalty Food Cost REIM  22899    NaN
# 3     Loyalty Sales Tax Payable  22899    NaN
# 3                TBD-Waiver-ROI  22899    NaN
# 3             TPD-Waiver_Ad-Fee  22899    NaN
# 4                  Batch Import  23339    NaN
# 4             DAI Royalty-23339  23339  23339
# 4             Faf-Royalty-23339  23339  23339
# 4                      Fees-Faf  23339    NaN
# 4                  Fees-Royalty  23339    NaN
# 4   Loyalty Food Cost Free REIM  23339    NaN
# 4        Loyalty Food Cost REIM  23339    NaN
# 4     Loyalty Sales Tax Payable  23339    NaN
# 4                TBD-Waiver-ROI  23339    NaN
# 4             TPD-Waiver_Ad-Fee  23339    NaN
# 5                  Batch Import  34497    NaN
# 5             DAI Royalty-34497  34497  34497
# 5             Faf-Royalty-34497  34497  34497
# 5                      Fees-Faf  34497    NaN
# 5                  Fees-Royalty  34497    NaN
# 5   Loyalty Food Cost Free REIM  34497    NaN
# 5        Loyalty Food Cost REIM  34497    NaN
# 5     Loyalty Sales Tax Payable  34497    NaN
# 5                TBD-Waiver-ROI  34497    NaN
# 5             TPD-Waiver_Ad-Fee  34497    NaN
# 6                  Batch Import  34939    NaN
# 6             DAI Royalty-34939  34939  34939
# 6             Faf-Royalty-34939  34939  34939
# 6                      Fees-Faf  34939    NaN
# 6                  Fees-Royalty  34939    NaN
# 6   Loyalty Food Cost Free REIM  34939    NaN
# 6        Loyalty Food Cost REIM  34939    NaN
# 6     Loyalty Sales Tax Payable  34939    NaN
# 6                TBD-Waiver-ROI  34939    NaN
# 6             TPD-Waiver_Ad-Fee  34939    NaN
# 7                  Batch Import  40929    NaN
# 7             DAI Royalty-40929  40929  40929
# 7             Faf-Royalty-40929  40929  40929
# 7                      Fees-Faf  40929    NaN
# 7                  Fees-Royalty  40929    NaN
# 7   Loyalty Food Cost Free REIM  40929    NaN
# 7        Loyalty Food Cost REIM  40929    NaN
# 7     Loyalty Sales Tax Payable  40929    NaN
# 7                TBD-Waiver-ROI  40929    NaN
# 7             TPD-Waiver_Ad-Fee  40929    NaN
# 8                  Batch Import  45790    NaN
# 8             DAI Royalty-45790  45790  45790
# 8             Faf-Royalty-45790  45790  45790
# 8                      Fees-Faf  45790    NaN
# 8                  Fees-Royalty  45790    NaN
# 8   Loyalty Food Cost Free REIM  45790    NaN
# 8        Loyalty Food Cost REIM  45790    NaN
# 8     Loyalty Sales Tax Payable  45790    NaN
# 8                TBD-Waiver-ROI  45790    NaN
# 8             TPD-Waiver_Ad-Fee  45790    NaN
# 9                  Batch Import   5453    NaN
# 9              DAI Royalty-5453   5453   5453
# 9              Faf-Royalty-5453   5453   5453
# 9                      Fees-Faf   5453    NaN
# 9                  Fees-Royalty   5453    NaN
# 9   Loyalty Food Cost Free REIM   5453    NaN
# 9        Loyalty Food Cost REIM   5453    NaN
# 9     Loyalty Sales Tax Payable   5453    NaN
# 9                TBD-Waiver-ROI   5453    NaN
# 9             TPD-Waiver_Ad-Fee   5453    NaN
# 11                 Batch Import   5763    NaN
# 11             DAI Royalty-5763   5763   5763
# 11             Faf-Royalty-5763   5763   5763
# 11                     Fees-Faf   5763    NaN
# 11                 Fees-Royalty   5763    NaN
# 11  Loyalty Food Cost Free REIM   5763    NaN
# 11       Loyalty Food Cost REIM   5763    NaN
# 11    Loyalty Sales Tax Payable   5763    NaN
# 11               TBD-Waiver-ROI   5763    NaN
# 11            TPD-Waiver_Ad-Fee   5763    NaN
# 12                 Batch Import  64160    NaN
# 12            DAI Royalty-64160  64160  64160
# 12            Faf-Royalty-64160  64160  64160
# 12                     Fees-Faf  64160    NaN
# 12                 Fees-Royalty  64160    NaN
# 12  Loyalty Food Cost Free REIM  64160    NaN
# 12       Loyalty Food Cost REIM  64160    NaN
# 12    Loyalty Sales Tax Payable  64160    NaN
# 12               TBD-Waiver-ROI  64160    NaN
# 12            TPD-Waiver_Ad-Fee  64160    NaN
# 13                 Batch Import    930    NaN
# 13              DAI Royalty-930    930    930
# 13              Faf-Royalty-930    930    930
# 13                     Fees-Faf    930    NaN
# 13                 Fees-Royalty    930    NaN
# 13  Loyalty Food Cost Free REIM    930    NaN
# 13       Loyalty Food Cost REIM    930    NaN
# 13    Loyalty Sales Tax Payable    930    NaN
# 13               TBD-Waiver-ROI    930    NaN
# 13            TPD-Waiver_Ad-Fee    930    NaN
# 0                  Batch Import  10086    NaN
# 0                CNP Fees-10086  10086    NaN
# 0                      Call Fee  10086    NaN
# 0        Cash Card Redeemed Fee  10086    NaN
# 0      Cash Card Redeemed-10086  10086    NaN
# 0    Cash Card Sales Commission  10086    NaN
# 0         Cash Card Sales-10086  10086    NaN
# 0    Catering Call Center-10086  10086    NaN
# 0         IPC Net Deposit-10086  10086    NaN
# 0              Paypal Fee-10086  10086    NaN
# 0                  Paypal-10086  10086    NaN
# 1                  Batch Import  10215    NaN
# 1                CNP Fees-10215  10215    NaN
# 1                      Call Fee  10215    NaN
# 1        Cash Card Redeemed Fee  10215    NaN
# 1      Cash Card Redeemed-10215  10215    NaN
# 1    Cash Card Sales Commission  10215    NaN
# 1         Cash Card Sales-10215  10215    NaN
# 1    Catering Call Center-10215  10215    NaN
# 1         IPC Net Deposit-10215  10215    NaN
# 1              Paypal Fee-10215  10215    NaN
# 1                  Paypal-10215  10215    NaN
# 2                  Batch Import   1717    NaN
# 2                 CNP Fees-1717   1717    NaN
# 2                      Call Fee   1717    NaN
# 2        Cash Card Redeemed Fee   1717    NaN
# 2       Cash Card Redeemed-1717   1717    NaN
# 2    Cash Card Sales Commission   1717    NaN
# 2          Cash Card Sales-1717   1717    NaN
# 2     Catering Call Center-1717   1717    NaN
# 2          IPC Net Deposit-1717   1717    NaN
# 2               Paypal Fee-1717   1717    NaN
# 2                   Paypal-1717   1717    NaN
# 3                  Batch Import  22899    NaN
# 3                CNP Fees-22899  22899    NaN
# 3                      Call Fee  22899    NaN
# 3        Cash Card Redeemed Fee  22899    NaN
# 3      Cash Card Redeemed-22899  22899    NaN
# 3    Cash Card Sales Commission  22899    NaN
# 3         Cash Card Sales-22899  22899    NaN
# 3    Catering Call Center-22899  22899    NaN
# 3         IPC Net Deposit-22899  22899    NaN
# 3              Paypal Fee-22899  22899    NaN
# 3                  Paypal-22899  22899    NaN
# 4                  Batch Import  23339    NaN
# 4                CNP Fees-23339  23339    NaN
# 4                      Call Fee  23339    NaN
# 4        Cash Card Redeemed Fee  23339    NaN
# 4      Cash Card Redeemed-23339  23339    NaN
# 4    Cash Card Sales Commission  23339    NaN
# 4         Cash Card Sales-23339  23339    NaN
# 4    Catering Call Center-23339  23339    NaN
# 4         IPC Net Deposit-23339  23339    NaN
# 4              Paypal Fee-23339  23339    NaN
# 4                  Paypal-23339  23339    NaN
# 5                  Batch Import  34497    NaN
# 5                CNP Fees-34497  34497    NaN
# 5                      Call Fee  34497    NaN
# 5        Cash Card Redeemed Fee  34497    NaN
# 5      Cash Card Redeemed-34497  34497    NaN
# 5    Cash Card Sales Commission  34497    NaN
# 5         Cash Card Sales-34497  34497    NaN
# 5    Catering Call Center-34497  34497    NaN
# 5         IPC Net Deposit-34497  34497    NaN
# 5              Paypal Fee-34497  34497    NaN
# 5                  Paypal-34497  34497    NaN
# 6                  Batch Import  34939    NaN
# 6                CNP Fees-34939  34939    NaN
# 6                      Call Fee  34939    NaN
# 6        Cash Card Redeemed Fee  34939    NaN
# 6      Cash Card Redeemed-34939  34939    NaN
# 6    Cash Card Sales Commission  34939    NaN
# 6         Cash Card Sales-34939  34939    NaN
# 6    Catering Call Center-34939  34939    NaN
# 6         IPC Net Deposit-34939  34939    NaN
# 6              Paypal Fee-34939  34939    NaN
# 6                  Paypal-34939  34939    NaN
# 7                  Batch Import  40929    NaN
# 7                CNP Fees-40929  40929    NaN
# 7                      Call Fee  40929    NaN
# 7        Cash Card Redeemed Fee  40929    NaN
# 7      Cash Card Redeemed-40929  40929    NaN
# 7    Cash Card Sales Commission  40929    NaN
# 7         Cash Card Sales-40929  40929    NaN
# 7    Catering Call Center-40929  40929    NaN
# 7         IPC Net Deposit-40929  40929    NaN
# 7              Paypal Fee-40929  40929    NaN
# 7                  Paypal-40929  40929    NaN
# 8                  Batch Import  45790    NaN
# 8                CNP Fees-45790  45790    NaN
# 8                      Call Fee  45790    NaN
# 8        Cash Card Redeemed Fee  45790    NaN
# 8      Cash Card Redeemed-45790  45790    NaN
# 8    Cash Card Sales Commission  45790    NaN
# 8         Cash Card Sales-45790  45790    NaN
# 8    Catering Call Center-45790  45790    NaN
# 8         IPC Net Deposit-45790  45790    NaN
# 8              Paypal Fee-45790  45790    NaN
# 8                  Paypal-45790  45790    NaN
# 9                  Batch Import   5453    NaN
# 9                 CNP Fees-5453   5453    NaN
# 9                      Call Fee   5453    NaN
# 9        Cash Card Redeemed Fee   5453    NaN
# 9       Cash Card Redeemed-5453   5453    NaN
# 9    Cash Card Sales Commission   5453    NaN
# 9          Cash Card Sales-5453   5453    NaN
# 9     Catering Call Center-5453   5453    NaN
# 9          IPC Net Deposit-5453   5453    NaN
# 9               Paypal Fee-5453   5453    NaN
# 9                   Paypal-5453   5453    NaN
# 11                 Batch Import   5763    NaN
# 11                CNP Fees-5763   5763    NaN
# 11                     Call Fee   5763    NaN
# 11       Cash Card Redeemed Fee   5763    NaN
# 11      Cash Card Redeemed-5763   5763    NaN
# 11   Cash Card Sales Commission   5763    NaN
# 11         Cash Card Sales-5763   5763    NaN
# 11    Catering Call Center-5763   5763    NaN
# 11         IPC Net Deposit-5763   5763    NaN
# 11              Paypal Fee-5763   5763    NaN
# 11                  Paypal-5763   5763    NaN
# 12                 Batch Import  64160    NaN
# 12               CNP Fees-64160  64160    NaN
# 12                     Call Fee  64160    NaN
# 12       Cash Card Redeemed Fee  64160    NaN
# 12     Cash Card Redeemed-64160  64160    NaN
# 12   Cash Card Sales Commission  64160    NaN
# 12        Cash Card Sales-64160  64160    NaN
# 12   Catering Call Center-64160  64160    NaN
# 12        IPC Net Deposit-64160  64160    NaN
# 12             Paypal Fee-64160  64160    NaN
# 12                 Paypal-64160  64160    NaN
# 13                 Batch Import    930    NaN
# 13                 CNP Fees-930    930    NaN
# 13                     Call Fee    930    NaN
# 13       Cash Card Redeemed Fee    930    NaN
# 13       Cash Card Redeemed-930    930    NaN
# 13   Cash Card Sales Commission    930    NaN
# 13          Cash Card Sales-930    930    NaN
# 13     Catering Call Center-930    930    NaN
# 13          IPC Net Deposit-930    930    NaN
# 13               Paypal Fee-930    930    NaN
# 13                   Paypal-930    930    NaN
#
# [4914 rows x 9 columns]
